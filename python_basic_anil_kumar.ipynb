# %% [markdown]
# <a href="https://colab.research.google.com/github/olibirianilkumar67-collab/My-first-repo/blob/main/python_basic_anil_kumar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 1:Variables and dara types

# %%
name = "O Anil Kumar"
age = 27
height = 1.71
is_student = True

#Print all values in a single statement
print(name, age, height, is_student)
# Out:
# O Anil Kumar 27 1.71 True

# %% [markdown]
# Task 2: Sring Formatting

# %%
print(f"{name} | Age: {age} | height:{height} | Student: {is_student}")
# Out:
# O Anil Kumar | Age: 27 | height:1.71 | Student: True

# %% [markdown]
# Task 3: Arthmetic Operations

# %%
age_in_months = age*12
age_in_days = age*365
remainder = age % 7
age_square = age**2

# %%
print("\n--- Age Calculations---")
print("Age in number", age_in_months)
print("Age in days", age_in_days)
print("Remainder when age is divided by 7:", remainder)
print("Square of age", age_square)
# Out:
# --- Age Calculations---
# Age in number 324
# Age in days 9855
# Remainder when age is divided by 7: 6
# Square of age 729
