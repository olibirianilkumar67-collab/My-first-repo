# %%
print("what is the difference between hardware and software? Given examples")
# Out:
# what is the difference between hardware and software? Given examples

# %% [markdown]
# what is the difference between hardware and software? Given examples.
#
# Hardware refers to the physical, tangible components of a computer system that you can touch and see examples are monitor, CPU, while software consists of intangible instructions, data, or programs that tell the hardware what to do examples are Windows OS, browsers.
# Hardware is manufactured, whereas software is developed.
